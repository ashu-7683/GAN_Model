# %%
import matplotlib.pyplot as ply

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
df=pd.read_csv('Book1.csv')
df.head
x=df['BMI']
y=df['CHARGES']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_test=42)
model=LinearRegression()
model.fit(x_train,y_train)
beta_1=model.coef_[0]
beta_0=model.intercept_
y_pred=model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("model evaluation:")
print(f"mean square error,{mse}")
print(f"r2,{r2}")
plt.scatter(x,y,color="blue",label="datapoints")
plt.plot(x_test,y_pred,color="red",label="regressionline")
plt.xlabel("independent variable")
plt.ylabel("dependent variable")
plt.title("simple linear regresssion")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       6 x=df['BMI']
#       7 y=df['CHARGES']
# ----> 8 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_test=42)
#       9 model=LinearRegression()
#      10 model.fit(x_train,y_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
# --> 191 params = func_sig.bind(*args, **kwargs)
#     192 params.apply_defaults()
#     194 # ignore self/cls and positional/keyword markers
#
# File C:\ProgramData\anaconda3\Lib\inspect.py:3273, in Signature.bind(self, *args, **kwargs)
#    3268 def bind(self, /, *args, **kwargs):
#    3269     """Get a BoundArguments object, that maps the passed `args`
#    3270     and `kwargs` to the function's signature.  Raises `TypeError`
#    3271     if the passed arguments can not be bound.
#    3272     """
# -> 3273     return self._bind(args, kwargs)
#
# File C:\ProgramData\anaconda3\Lib\inspect.py:3262, in Signature._bind(self, args, kwargs, partial)
#    3252         raise TypeError(
#    3253             'got some positional-only arguments passed as '
#    3254             'keyword arguments: {arg!r}'.format(
#    (...)
#    3259             ),
#    3260         )
#    3261     else:
# -> 3262         raise TypeError(
#    3263             'got an unexpected keyword argument {arg!r}'.format(
#    3264                 arg=next(iter(kwargs))))
#    3266 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'random_test'
