# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load and prepare data
df = pd.read_csv('../datasets/Book1.csv')
x = df['BMI'].values.reshape(-1, 1)  # Reshape for single feature
y = df['CHARGES'].values

# Split data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Train model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Output results
print("Model Evaluation:")
print(f"Slope (beta_1): {model.coef_[0]:.2f}")
print(f"Intercept (beta_0): {model.intercept_:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")

# Plot results
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color="blue", alpha=0.5, label="Data points")
plt.plot(x_test, y_pred, color="red", linewidth=2, label="Regression line")
plt.xlabel("BMI")
plt.ylabel("Medical Charges")
plt.title("Linear Regression: BMI vs Medical Charges")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:1211: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Model Evaluation:
# Slope (beta_1): -1817.64
# Intercept (beta_0): 62891.24
# Mean Squared Error: 46448.26
# R² Score: nan
